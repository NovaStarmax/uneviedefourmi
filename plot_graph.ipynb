# %%
import matplotlib.pyplot as plt
import networkx as nx
from txt_to_graph import *

# Registre pour conserver chaque graphe et sa position
GRAPHS = {}

# %% [markdown]
# Display options

# %%
options = dict(
    with_labels=True,
    node_size=1500,
    node_color="lightblue",
    arrowsize=20,
    font_size=12
)

# %% [markdown]
# # F0

# %%
G = nx.DiGraph([
    ("Sv", "S1"),  
    ("Sv", "S2"),  
    ("S1", "Sd"),  
    ("S2", "Sd"),
])

pos = {
    "Sv": (0, 0), 
    "S1": (1, 1),  
    "S2": (1, -1),  
    "Sd": (2, 0), 
}

# Sauvegarde
GRAPHS["F0"] = (G, pos)

nx.draw_networkx(G, pos, **options)

plt.axis("off")
plt.show()

# %% [markdown]
# # F1

# %%
G = nx.DiGraph([
    ("Sv", "S1"),  
    ("S1", "S2"),  
    ("S2", "Sd"),
])

pos = {
    "Sv": (0, 0),  
    "S1": (1, 0),  
    "S2": (2, 0),
    "Sd": (3, 0),  
}

# Sauvegarde
GRAPHS["F1"] = (G, pos)

nx.draw_networkx(G, pos, **options)

plt.axis("off")
plt.show()

# %% [markdown]
# # F2

# %%
G = nx.DiGraph([
    ("Sv", "S1"),  
    ("S1", "S2"),  
    ("S2", "Sd"),
    ("Sd", "Sv"),
])

pos = {
    "Sv": (0, 0),  
    "S1": (1, -0.5),  
    "S2": (2, -1),
    "Sd": (2, 1),  
}

# Sauvegarde
GRAPHS["F2"] = (G, pos)

nx.draw_networkx(G, pos, **options)

plt.axis("off")
plt.show()

# %% [markdown]
# # F3

# %%
G = nx.DiGraph([
    ("Sv", "S1"),
    ("S1", "S2"),
    ("S4", "Sd"),
    ("S1", "S4"),
    ("S2", "S3"),
])

pos = {
    "Sv": (0, 0),  
    "S1": (1, 0),  
    "S2": (2, 0),
    "S3": (3, 1),
    "S4": (3, -1),
    "Sd": (4, 0),
}

# Sauvegarde
GRAPHS["F3"] = (G, pos)

nx.draw_networkx(G, pos, **options)

plt.axis("off")
plt.show()

# %% [markdown]
# # F4

# %%
G = nx.DiGraph([
    
    ("S3", "S4"),
    ("S3", "S4"),
    ("S3", "S4"),
    ("Sv", "S1"),
    ("S1", "S2"),
    ("S2" ,"S4"),
    ("S4", "S5"),
    ("S5", "Sd"),
    ("S4", "S6"),
    ("S6", "Sd"),
    ("S1", "S3")
])

pos = {
    "Sv": (0, 0),  
    "S1": (1, 0),  
    "S2": (2, -1),
    "S3": (2, 1),
    "S4": (3, 0),
    "S5": (4, -1),
    "S6": (4, 1),
    "Sd": (5, 0),
}

# Sauvegarde
GRAPHS["F4"] = (G, pos)

nx.draw_networkx(G, pos, **options)

plt.axis("off")
plt.show()

# %% [markdown]
# # F5

# %%
G = nx.DiGraph([
    ("S1", "S2"),
    ("S2", "S3"),
    ("S3", "S4"),
    ("S4", "Sd"),
    ("Sv", "S1"),
    ("S2", "S5"),
    ("S5", "S4"),
    ("S13", "Sd"),
    ("S8", "S12"),
    ("S12", "S13"), 
    ("S6", "S7"),
    ("S7", "S9"),   
    ("S9", "S14"),  
    ("S14", "Sd"),  
    ("S7", "S10"),  
    ("S10", "S14"), 
    ("S1", "S6"),   
    ("S6", "S8"),   
    ("S8", "S11"),  
    ("S11", "S13"), 
])

pos = {
    "Sv":  (0, 0),      

    "S1":  (2, 0),      
    "S2":  (4, -2),     
    "S3":  (4, 1.5),      

    "S5":  (6, -3),     
    "S4":  (8, 0),      

    "S6":  (2, 4),      
    "S7":  (4, 6),      
    "S8":  (4, 4),      

    "S9":  (6, 8),      
    "S10": (6, 6),      
    "S11": (6, 4),      
    "S12": (6, 2),      

    "S13": (8, 3),      
    "S14": (8, 7),      

    "Sd":  (10, 0),     
}

# Sauvegarde
GRAPHS["F5"] = (G, pos)


nx.draw_networkx(G, pos, **options)

plt.axis("off")
plt.show()

# %%
G = nx.DiGraph([
    ("Sv", "S1"),
    ("S1", "S2"),
    ("S1", "S6"),
    ("S2", "S3"),
    ("S2", "S5"),
    ("S3", "S4"),
    ("S5", "S4"),
    ("S4", "Sd"),
    ("S6", "S7"),
    ("S6", "S8"),
    ("S7", "S9"),
    ("S7", "S10"),
    ("S9", "S14"),
    ("S10", "S14"),
    ("S14", "Sd"),
    ("S8", "S12"),
    ("S8", "S11"),
    ("S12", "S13"),
    ("S11", "S13"),
    ("S13", "Sd"),
])

pos = {
    "Sv":  (0, 0),
    "S1":  (1, 0),
    "S2":  (2, 1),
    "S6":  (2, -1.5),
    "S3":  (3, 1.5),
    "S5":  (3, 0.5),
    "S7":  (3, -0.8),
    "S8":  (3, -3),
    "S4":  (4, 1),
    "S9":  (4, -0.5),
    "S10": (4, -1.5),
    "S12": (4, -2.5),
    "S11": (4, -3.5),
    "S14": (5, -1),
    "S13": (5, -3),
    "Sd":  (6, -1),
}

nx.draw_networkx(G, pos, **options)
plt.axis("off")
plt.show()

# %%
# Affichage final: réutilise les graphes/positions déjà créés
labels = ["F0", "F1", "F2", "F3", "F4", "F5"]
fig, axes = plt.subplots(3, 2, figsize=(14, 18))
axes = axes.ravel()
for ax, key in zip(axes, labels):
    G, pos = GRAPHS.get(key, (None, None))
    if G is None:
        ax.set_title(f"{key} (non défini)")
        ax.axis('off')
        continue
    # Coloration: Sv en vert, Sd en rouge
    colors = [("#34a853" if n=='Sv' else ("#ea4335" if n=='Sd' else "#80c0ff")) for n in G.nodes]
    nx.draw_networkx(G, pos=pos, ax=ax, with_labels=True, node_size=1200, node_color=colors, arrowsize=18, font_size=11)
    ax.set_title(key)
    ax.axis('off')

plt.tight_layout()
plt.show()
